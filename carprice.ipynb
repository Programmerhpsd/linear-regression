# %% [markdown]
# <a href="https://colab.research.google.com/github/Programmerhpsd/linear-regression/blob/main/carprice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("test-data.csv")
df
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                            Maruti Alto K10 LXI CNG
# 1              1                      Maruti Alto 800 2016-2019 LXI
# 2              2          Toyota Innova Crysta Touring Sport 2.4 MT
# 3              3                               Toyota Etios Liva GD
# 4              4                                  Hyundai i20 Magna
# ...          ...                                                ...
# 1229        1229                  Volkswagen Vento Diesel Trendline
# 1230        1230                             Volkswagen Polo GT TSI
# 1231        1231                             Nissan Micra Diesel XV
# 1232        1232                             Volkswagen Polo GT TSI
# 1233        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# ...

# %%
df[["Name","Year","Seats"]]
df.head(10)
df[["Name","Year","Seats"]]
# Out:
#                                                    Name  Year  Seats
# 0                               Maruti Alto K10 LXI CNG  2014    4.0
# 1                         Maruti Alto 800 2016-2019 LXI  2013    5.0
# 2             Toyota Innova Crysta Touring Sport 2.4 MT  2017    7.0
# 3                                  Toyota Etios Liva GD  2012    5.0
# 4                                     Hyundai i20 Magna  2014    5.0
# ...                                                 ...   ...    ...
# 1229                  Volkswagen Vento Diesel Trendline  2011    5.0
# 1230                             Volkswagen Polo GT TSI  2015    5.0
# 1231                             Nissan Micra Diesel XV  2012    5.0
# 1232                             Volkswagen Polo GT TSI  2013    5.0
# 1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...  2014    5.0
#
# [1234 rows x 3 columns]

# %%
plt.xlabel("year")
plt.ylabel("seats")
plt.scatter(df.Year,df.Kilometers_Driven)

# %%
reg=linear_model.LinearRegression()
reg.fit(df[["Year"]],df.Kilometers_Driven)
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([24871.74404388])
