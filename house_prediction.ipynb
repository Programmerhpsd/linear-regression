# %% [markdown]
# <a href="https://colab.research.google.com/github/Programmerhpsd/linear-regression/blob/main/house_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("data.csv")
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df[["sqft_living","bedrooms"]]
# Out:
#       sqft_living  bedrooms
# 0            1340       3.0
# 1            3650       5.0
# 2            1930       3.0
# 3            2000       3.0
# 4            1940       4.0
# ...           ...       ...
# 4595         1510       3.0
# 4596         1460       3.0
# 4597         3010       3.0
# 4598         2090       4.0
# 4599         1490       3.0
#
# [4600 rows x 2 columns]

# %%
plt.xlabel("living area")
plt.ylabel("bedroom")
plt.scatter(df.sqft_living,df.bedrooms)

# %%
reg=linear_model.LinearRegression()
reg.fit(df[["sqft_living"]],df.bedrooms)
# Out:
# LinearRegression()

# %%
reg.predict([[1490]])
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.03638356])
